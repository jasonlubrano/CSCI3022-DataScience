# %% [markdown]
# <a id='top'></a>
#
# # Homework 1: Data Cleaning and Exploratory Data Analysis
# ***
#
# **Name**:
#
# ***
#
# This assignment is due on Canvas by **5 PM on Friday February 1**. Your solutions to theoretical questions should be done in Markdown directly below the associated question.  Your solutions to computational questions should include any specified Python code and results as well as written commentary on your conclusions.  Remember that you are encouraged to discuss the problems with your classmates, but **you must write all code and solutions on your own**.
#
# **NOTES**:
#
# - Any relevant data sets should be available under the **Data** module on Canvas. To make life easier on the graders if they need to run your code, do not change the relative path names here. Instead, move the files around on your computer.
# - If you're not familiar with typesetting math directly into Markdown then by all means, do your work on paper first and then typeset it later.  Remember that there is a [reference guide](https://math.meta.stackexchange.com/questions/5020/mathjax-basic-tutorial-and-quick-reference) linked on Canvas on writing math in Markdown. **All** of your written commentary, justifications and mathematical work should be in Markdown.
# - Because you can technically evaluate notebook cells is a non-linear order, it's a good idea to do Kernel $\rightarrow$ Restart & Run All as a check before submitting your solutions.  That way if we need to run your code you will know that it will work as expected.
# - It is **bad form** to make your reader interpret numerical output from your code.  If a question asks you to compute some value from the data you should show your code output **AND** write a summary of the results in Markdown directly below your code.
# - This probably goes without saying, but... For any question that asks you to calculate something, you **must show all work and justify your answers to receive credit**. Sparse or nonexistent work will receive sparse or nonexistent credit.
#
# ---
# **Shortcuts:**  [Problem 1](#p1) | [Problem 2](#p2) | [Problem 3](#p3) | [Problem 4](#p4) | [Problem 5](#p5)
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline

# %% [markdown]
# [Back to top](#top)
#
# <br>
#
# <a/ id='p1'></a>
#
# ### (10 pts) Problem 1
# ***
#
# ![hedgehog](https://www.irishexaminer.com/remote/media.central.ie/media/images/h/hedgehog17_large.jpg?width=648&s=ie-467290)
#
# Hedgehogs are undeniably one of the cutest creatures in all of the land, so the University of Colorado Boulder wants to switch its mascot to the hedgehog. Before making the switch, the CU officials need to know whether they will be able to find new hedgehog mascot handlers, similar to the current Ralphie handlers. You are called upon to perform an experiment to order to determine how fit CU Boulder students are for hedgehog-handling. There are too many students at CU for you to test all of their **Hedgehog-Handling Ability** (HHA), so from a roster of all students and their majors, you will randomly test the HHA of one-tenth of the majors from each department on campus. (Assume nobody is a double major, and assume that everybody has a major.) From this sample, you will estimate the mean HHA of all students on campus, and let the CU officials know whether or not CU students will be able to handle hedgehogs.
#
# Identify the following:
#
# - the population
# - the sample frame
# - the sample
# - the type of sample
# - the quantity of interest

# %% [markdown]
# Population: CU Boulder Students
#
# Sample Frame: Roster of all students and their majors
#
# Sample: Students from 1/10th of the major from each department
#
# Type of Sample: Stratified sampling
#
# Quantity of Interest: Hedgehog-handling ability(HHA)

# %% [markdown]
# [Back to top](#top)
#
# <br>
#
# <a/ id='p2'></a>
#
# ### (20 pts) Problem 2
# ***
#
# A method to investigate the sensitivity of the sample mean and the sample median to extreme outliers and changes in the dataset is to replace one or more elements in a given dataset by a number $y$ and investigate the eﬀect when $y$ changes. To illustrate this, consider the dataset
#
# $$
# y \quad
# 5.4 \quad
# 5.0 \quad
# 6.5 \quad
# 7.7 \quad
# 6.0 \quad
# 1.9
# $$

# %% [markdown]
# **Part A**: Compute the sample mean and sample median for $y=2$. Compute them both again for $y=8$.

# %% [markdown]
# Let $y=2$:
# $$
# 1.9 \quad
# 2 \quad
# 5.0 \quad
# 5.4 \quad
# 6.0 \quad
# 6.5 \quad
# 7.7
# $$
#
# mean:
# $$
# \bar{x}=\frac{1}{n}\sum_{k=1}^n x_k = \frac{(1.9 + 2 + 5.0 + 5.4 + 6.0 + 6.5 + 7.7)}{7} = 4.9\ldots
# $$
#
# median:
# $$
# 5.4
# $$
#
#
# Let $y=8$:
# $$
# 1.9 \quad
# 5.0 \quad
# 5.4 \quad
# 6.0 \quad
# 6.5 \quad
# 7.7 \quad
# 8
# $$
#
# mean:
# $$
# \bar{x}=\frac{1}{n}\sum_{k=1}^n x_k = \frac{(1.9 + 5.0 + 5.4 + 6.0 + 6.5 + 7.7 + 8)}{7} = 5.7\ldots
# $$
#
# median:
# $$
# 6.0
# $$

# %% [markdown]
# **Part B**: Is there a value for $y$ that would make the mean of those data equal to $4$? If so, calculate the value of $y$ that makes the mean equal to $4$. If not, clearly explain why not.
#
# Is there a value for $y$ that would make the median of those data equal to $4$? If so, calculate the value of $y$ that makes the median equal to $4$. If not, clearly explain why not.

# %% [markdown]
# Find $y$ such that $\bar{x}=4$. Let $\bar{x}=4$:
# \begin{align*}
#     4   &= \frac{1}{n}\sum_{k=1}^n x_k \\
#         &= \frac{(1.9 + 5.0 + 5.4 + 6.0 + 6.5 + 7.7 + y)}{7} \\
#     28  &= 32.5 + y \\
#     y   &= {-4.5}\\
# \end{align*}

# %% [markdown]
# There is no value for $y$ that would make the median $\tilde{x} = 4$. Based on the value of $y$ explained in part D, $\tilde{x}$ can only be three sets of values.
# There are three different sets of outcomes for $\tilde{x}$ based on $y$;
# - If: $ y \le 5.4 \rightarrow \tilde{x} = 5.4 $
#
# - If: $ 5.4 \lt y \text{ and } y \lt 6.0 \rightarrow \tilde{x} = y $
#
# - If: $ 6.0 \le y \rightarrow \tilde{x} = 6.0 $
#
# Therefore, there is no value for $y$ such that $\tilde{x}=4$

# %% [markdown]
# **Part C**: Compute the sample median for the following cases:
# - $y=5$
# - $y=50$
# - $y=5.39$
# - $y=5.41$
# - $y \to \infty$
# - $y \to -\infty$

# %% [markdown]
# - Let $y=5$:
# $
# \quad
# 1.9 \quad
# \textbf{5} \quad
# 5.0 \quad
# 5.4 \quad
# 6.0 \quad
# 6.5 \quad
# 7.7
# $
#
# median: $\tilde{x} = 5.4$
#
# - Let $y=50$:
# $
# \quad
# 1.9 \quad
# 5.0 \quad
# 5.4 \quad
# 6.0 \quad
# 6.5 \quad
# 7.7 \quad
# \textbf{50}
# $
#
# median: $\tilde{x} = 6.0$
#
# - Let $y=5.39$:
# $
# \quad
# 1.9 \quad
# 5.0 \quad
# \textbf{5.39} \quad
# 5.4 \quad
# 6.0 \quad
# 6.5 \quad
# 7.7
# $
#
# median: $\tilde{x} = 5.4$
#
# - Let $y=5.41$:
# $
# \quad
# 1.9 \quad
# 5.0 \quad
# 5.4 \quad
# \textbf{5.41} \quad
# 6.0 \quad
# 6.5 \quad
# 7.7
# $
#
# median: $\tilde{x} = 5.41$
#
# - Let $y \to \infty$:
# $
# \quad
# 1.9 \quad
# 5.0 \quad
# 5.4 \quad
# 6.0 \quad
# 6.5 \quad
# 7.7 \quad
# \mathbf{\infty}
# $
#
# median: $\tilde{x} = 6.0$
#
#
# - Let $y \to \mathbf{{-\infty}}$:
# $
# \quad
# \mathbf{{-\infty}}\quad
# 1.9 \quad
# 5.0 \quad
# 5.4 \quad
# 6.0 \quad
# 6.5 \quad
# 7.7
# $
#
# median: $\tilde{x} = 5.4$

# %% [markdown]
# **Part D**: Think about the previous parts, above, and describe in words or mathematical notation the answers to the following two questions:
#
# - By varying $y$, what is the set of all the possible values that the sample mean could take on?
# - By varying $y$, what is the set of all the possible values that the sample median could take on? Specifically,
# for what sets of $y$ values does the median take on its different possible values?

# %% [markdown]
# There are $2$ different outcomes for the mean:
# - As $y$ approaches $\infty$, $\bar{x} = \infty$:
# $$
# \bar{x} = \lim_{y\rightarrow\infty}{\frac{y + 1.9 + 5.0 + 5.4 + 6.0 + 6.5 + 7.7}{7}} = \infty
# $$
# - As $y$ approaches ${-\infty}$, $\bar{x} = {-\infty}$:
# $$
# \bar{x} = \lim_{y\rightarrow{-\infty}}{\frac{y + 1.9 + 5.0 + 5.4 + 6.0 + 6.5 + 7.7}{7}} = {-\infty}
# $$
# - Therefore, the range of $\bar{x}$ equals ${-\infty} \text{ to } \infty$
# $$
# {-\infty} \le \bar{x} \le \infty
# $$
# There are $3$ different sets of outcomes for the median ($\tilde{x}$) based on the value of $y$:
# - If: $ y \le 5.4 \rightarrow \tilde{x} = 5.4 $
#
# - If: $ 5.4 \lt y \text{ and } y \lt 6.0 \rightarrow \tilde{x} = y $
#
# - If: $ 6.0 \le y \rightarrow \tilde{x} = 6.0 $

# %% [markdown]
# [Back to top](#top)
#
# <br>
#
# <a/ id='p3'></a>
#
# ### (20 pts) Problem 3
# ***
#
# Let $x_1, x_2, \ldots, x_n$ be $n$ observations of a variable of interest.  Recall that the sample mean $\bar{x}_n$ and sample variance $s^2_n$ are given by
#
# $$
# \bar{x}_n = \frac{1}{n}\sum_{k=1}^n x_k \quad \textrm{and} \quad s^2_n = \frac{1}{n-1}\sum_{k=1}^n \left( x_k - \bar{x}_n\right)^2 \qquad \tag{Equation 1}
# $$
#
# where here the subscript $n$'s indicate the number of observations in the sample. Notice that a natural computation of the variance requires two passes over the data: one to compute the mean, and a second to subtract the mean from each observation and compute the sum of squares. It is often useful to be able to compute the variance in a single pass, inspecting each value $x_k$ only once; for example, when the data are being collected without enough storage to keep all the values, or when costs of memory access dominate those of computation. In this problem you will explore two methods for such an _online_ computation of the mean.
#
# **Part A**: Show algebraically that the following relation holds between the mean of the first $n-1$ observations and the mean of all $n$ observations:
#
# $$
# \bar{x}_n = \bar{x}_{n-1} + \frac{x_n - \bar{x}_{n-1}}{n}
# $$
#
# Note that you can get an expression for $\bar{x}_{n-1}$ by simply replacing $n$ in Equation 1 above with $n-1$.

# %% [markdown]
# \begin{align}
# \bar{x}_{n} &= \bar{x}_{n-1}+\frac{x_{n}-\bar{x}_{n-1}}{n}\\
#     &= \frac{n\bar{x}_{n-1} + x_{n} - \bar{x}_{n-1}}{n} \\
#     &= \frac{n\bar{x}_{n-1} - \bar{x}_{n-1} + x_{n}}{n} \\
#     &= \frac{\bar{x}_{n-1}(n-1) + x_{n}}{n} \\
# n\bar{x}_{n} &= \bar{x}_{n-1}(n-1) + x_{n} \\
# n\bar{x}_{n} - x_n &= \bar{x}_{n-1}(n-1) \\
# x_{n}(n - 1) &= \bar{x}_{n-1}(n-1) \\
# x_{n} &= \bar{x}_{n-1}
# \end{align}

# %% [markdown]
# **Part B**: Write a function `my_sample_mean` that takes as its input a numpy array and returns the mean of that numpy array using the formulas from class (written above). Write another function `my_sample_var` that takes as its input a numpy array and returns the variance of that numpy array, again using the formulas from class (written above). You may **not** use any built-in sample mean or variance functions.

# %%
def my_sample_mean(arr):
    lenarr = len(arr)
    #print(lenarr)
    sumarr=sum(arr)
    #print(sumarr)
    avg = sumarr/lenarr
    return(avg)

def my_sample_var(arr):
    meanarr = my_sample_mean(arr)
    #print(meanarr)
    arr1=[]
    for a in range(len(arr)):
        arr1.append((arr[a]-meanarr)**2)
    #print(arr1)
    sumarr1 = sum(arr1)
    #print(sumarr1)
    lenarr1 = len(arr1)-1
    print(lenarr1)
    sampvar = sumarr1 / lenarr1
    return(sampvar)

hha = [98, 26, 83, 56, 60, 39, 81, 19, 72, 78, 94, 42]
hha1 = [1.5, 4, 1, 2.5, 2, 1]
#my_sample_mean(hha)
my_sample_var(hha)
# Out:
# 11
# 690.060606060606

# %% [markdown]
# **Part C**: Use your functions from Part B to compute the sample mean and sample variance of the following array, which contains the hedgehog-handling abilities (HHA) of a sample of 12 CU Boulder hedgehog handlers.
#
# `hha = [98, 26, 83, 56, 60, 39, 81, 19, 72, 78, 94, 42]`

# %%
mysamplemean = my_sample_mean(hha)
mysamplevar = my_sample_var(hha)
print(mysamplemean)
print(mysamplevar)
# Out:
# 11
# 62.333333333333336
# 690.060606060606

# %% [markdown]
# **Part D**: Implement a third function called `update_mean` that implements the formula whose validity you proved in Part A. Note that this function will need to take as its input three things: $x_n$, $\bar{x}_{n-1}$ and $n$. A function header is provided for you. This function may be auto-graded, so please do not change the given API - the order of inputs matters! If you change it, you might lose points.
#
# Use this function to compute the values that you get from taking the mean of the first hedgehog handler, the first two hedgehog handlers, the first three hedgehog handlers, and so on up to all of the hedgehog handler data points. Store your HHA means in a numpy array called `hha_means`.  Report all 12 estimates in `hha_means`.

# %%
# Given API:
def update_mean(prev_mean, xn, n):
    #prev_mean x-
    #xn new value
    #n new count
    #n-1 old count
    # your code goes here!
    updatedmean=((prev_mean*(n-1))+xn)/(n)
    return updatedmean #the updazed mean

# %% [markdown]
# To ensure your function complies with the given API, run this small test, where we suppose we have a mean of $\bar{x}_n = 1$ with the first $2$ data points (`prev_mean`), and we update this with the 3rd ($n=3$) data point which is $x_3=2$:

# %%
assert update_mean(1,2,3)==4/3, "Warning: function seems broken."

# %%
def hhameans(arr):
    hha_means=[]
    for a in range(len(arr)):
        #print(a)
        if(a==0):
            hha_means.append(arr[a])
        else:
            prev_mean = hha_means[a-1]
            #print(prev_mean)
            hha_means.append(update_mean(prev_mean, arr[a], a+1))
        #print(hha_means)
    return(hha_means)

hha_means=hhameans(hha)
print(hha_means)
#print(hha) hha = [98, 26, 83, 56, 60, 39, 81, 19, 72, 78, 94, 42]
# Out:
# [98, 62.0, 69.0, 65.75, 64.6, 60.333333333333336, 63.285714285714285, 57.75, 59.333333333333336, 61.2, 64.18181818181819, 62.333333333333336]

# %% [markdown]
# [Back to top](#top)
#
# <br>
#
# <a/ id='p4'></a>
#
# ### (25 pts) Problem 4
# ***
# Some claim that the final hours aboard the RMS Titanic were marked by "class warfare" in which the people with first-class tickets took all the good spots on the lifeboats; others claim that the final hours were characterized by male chivalry, in which the men valiantly gave up their positions in the boats and succumbed bravely to the depths of the Atlantic.
#
# We have the data on survival rates by class and by sex, so let's figure out whether there is evidence for these scenarios. Access the Titanic data in `titanic_data.csv` and store it in a Pandas DataFrame. The data contains information pertaining to class status (**Pclass**), survival (**Survived**), and gender (**Sex**) of passengers, among other things. Be sure to use the `titanic_data.csv` data set, *not* the `clean_titanic_data` file from the in-class notebook.

# %%
df = pd.read_csv("titanic_data.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  36.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  18.0      1
# 2                             Heikkinen, Miss. Laina  female  14.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  27.0      1
# 4                           Allen, Mr. William Henry    male  63.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# **Part A**: Consider the two claims: class warfare, and male chivalry. Suppose that class warfare occurred in the final hours aboard the Titanic.  What patterns might you expect to see in the data?  Suppose that male chivalry was widespread during the final hours instead. What patterns might you then expect to see in the data?  Explain both of these hypothesized patterns in words. Are these two hypotheses mutually exclusive or not?

# %% [markdown]
# If class warefare existed, I'd imagine the peasants were left to drown and freeze while the eliteist were the first to use the lifeboats and rafts, from where they will poke at the peasants in the water below. Therefore, more elites than peasants would survive. It may be safe to say that the children that survived were from higher class families rather than lower end ones.
#
# If chivalry existed instead, its "women and children" first. More children and women, regardless of class would survive. There would be a lack of men from all classes to survive.

# %% [markdown]
# **Part B**: Use Pandas methods to create a clean data set by removing any rows from the DataFrame that are missing values corresponding to **Survived**, **Pclass**, **Age**, or **Sex**. Store the clean data in a DataFrame called dfTitanic. Be sure to show any exploratory work determining if/where there are rows with missing values.

# %%
dfTitanic = df.dropna(subset=['Age', 'Survived', 'Pclass', 'Sex'])
dfTitanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 10            11         1       3
# 11            12         0       1
# 13            14         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         0       3
# 23            24         1       1
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 32            33         1       3
# 33            34         0       2
# ...

# %% [markdown]
# **Part C**: Compute the fraction of survivors according to class and gender. There are 3 passenger classes and 2 sexes in the data set, so you should report all 6 possible combinations.  Then, answer 3 questions:
# * **(i)** Within each passenger class, were men or women more/less/equally likely to survive?
# * **(ii)**  Looking at only the male or only the female passengers, how is passenger class related to the category's survival rate?
#
# * **(iii)**  Did men in first class or women in third class have a higher survival rate?

# %%
# total amount of peeps on the boat with info
count_row = dfTitanic.shape[0]
print(count_row, "total people on the ship with information.")

# total survivors with info
sur = ((dfTitanic["Survived"]==1)).sum()
print("{} peeps survived the disaster".format(sur))

# total women survived
f_sur = ((dfTitanic["Survived"]==1) & (dfTitanic["Sex"]=='female')).sum()
print("{} women survived the disaster".format(f_sur))

# total men survived
m_sur = ((dfTitanic["Survived"]==1) & (dfTitanic["Sex"]=='male')).sum()
print("{} men survived the disaster".format(m_sur))

# Females in Pclass
f_sur_1 = ((dfTitanic["Survived"]==1) & (dfTitanic["Pclass"]==1) & (dfTitanic["Sex"]=='female')).sum()
print("{} women in Pclass 1 survived the disaster".format(f_sur_1))
f_sur_2 = ((dfTitanic["Survived"]==1) & (dfTitanic["Pclass"]==2) & (dfTitanic["Sex"]=='female')).sum()
print("{} women in Pclass 2 survived the disaster".format(f_sur_2))
f_sur_3 = ((dfTitanic["Survived"]==1) & (dfTitanic["Pclass"]==3) & (dfTitanic["Sex"]=='female')).sum()
print("{} women in Pclass 3 survived the disaster".format(f_sur_3))

# Males in Pclass
m_sur_1 = ((dfTitanic["Survived"]==1) & (dfTitanic["Pclass"]==1) & (dfTitanic["Sex"]=='male')).sum()
print("{} men in Pclass 1 survived the disaster".format(m_sur_1))
m_sur_2 = ((dfTitanic["Survived"]==1) & (dfTitanic["Pclass"]==2) & (dfTitanic["Sex"]=='male')).sum()
print("{} men in Pclass 2 survived the disaster".format(m_sur_2))
m_sur_3 = ((dfTitanic["Survived"]==1) & (dfTitanic["Pclass"]==3) & (dfTitanic["Sex"]=='male')).sum()
print("{} men in Pclass 3 survived the disaster".format(m_sur_3))

# Genderless in Pclass
p_sur_1 = ((dfTitanic["Survived"]==1) & (dfTitanic["Pclass"]==1)).sum()
print("{} passengers in Pclass 1 survived the disaster".format(p_sur_1))
p_sur_2 = ((dfTitanic["Survived"]==1) & (dfTitanic["Pclass"]==2)).sum()
print("{} passengers in Pclass 2 survived the disaster".format(p_sur_2))
p_sur_3 = ((dfTitanic["Survived"]==1) & (dfTitanic["Pclass"]==3)).sum()
print("{} passengers in Pclass 3 survived the disaster".format(p_sur_3))
# Out:
# 714 total people on the ship with information.
# 279 peeps survived the disaster
# 188 women survived the disaster
# 91 men survived the disaster
# 72 women in Pclass 1 survived the disaster
# 54 women in Pclass 2 survived the disaster
# 62 women in Pclass 3 survived the disaster
# 36 men in Pclass 1 survived the disaster
# 16 men in Pclass 2 survived the disaster
# 39 men in Pclass 3 survived the disaster
# 108 passengers in Pclass 1 survived the disaster
# 70 passengers in Pclass 2 survived the disaster
# 101 passengers in Pclass 3 survived the disaster

# %% [markdown]
# * **(i)** Within each passenger class, were men or women more/less/equally likely to survive?
#
# Based on the data more women survived than men. While 74 women survived, only 37 men survived. It seems as though women were twice as likely to survive as men.
#
# * **(ii)**  Looking at only the male or only the female passengers, how is passenger class related to the category's survival rate?
#
# Between both sexes, the consistent trend shows that the higher the class the more likely the survival rate would be. The majority of the survivors, 84%, were in first class.
#
# * **(iii)**  Did men in first class or women in third class have a higher survival rate?
#
# There were 74 women that survived. Of those women, only 4 were in third class. Women in third class made up of around 3% of total survivors.
# There were 37 men that survived and of those men 31 were in first class. Men in first class made up of around 28% of survivors.
# Men in first class had a much higher rate of survival than the women in third class did.

# %% [markdown]
# **Part D**: Plot a histogram of all of the passenger ages, using the bin edges $[0,5,10,\ldots,70,75,80]$ defined by `my_bins` below. How would you characterize the distribution of **AGE**? (By _characterize_ we mean that you should indicate whether the data are unimodal, bimodal, multimodal, symmetric, negatively skewed, positively skewed, etc.)  Be sure to label your axes and use your figure to justify your conclusions.

# %%
my_bins = range(0,85,5)

# %%
print("bin edges = ", list(my_bins))
# Initialize figure 
fig, ax0 = plt.subplots(figsize=(16,8))

# Plot histogram
dfTitanic.hist(column="Age", ax=ax0, bins=my_bins,
               color='sienna', edgecolor = 'black',); #bob ross colors dont show up :( #

# Add labels
plt.title('Age of Passengers on Titanic')
plt.xlabel('Age')
plt.ylabel('Number of Passengers')
# Out:
# bin edges =  [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75, 80]
# Text(0, 0.5, 'Number of Passengers')

# %% [markdown]
# I would classify this data as unimodal. There are three main humps: children under 5, young adults from 25 to 30, and then another one of older folk from 50 to 55. Even though there are three humps, the only one that is highly pronounced is the young adults from 25 to 30. I would say this graph is positively skewed as well. This graph has a long-tail that veers off to the right. By eyeballing it, I would say the median is higher than the mode(25), and the mean would be higher than the median.

# %% [markdown]
# **Part E**: One might wonder how a passenger's age is related to the likelihood that they would survive the Titanic disaster. To answer this question graphically, plot two density histograms on the same set of axes, showing the distribution of the ages of passengers who survived, and the distribution of the ages of passengers who did not.
# * Use the bin edges $[0,5,10,\ldots,70,75,80]$ for both histograms.
# * This problem is about a *ship* sinking in the *ocean*, so use **coral** and **seagreen** as the facecolors for your histogram boxes.
# * Plot both histograms on a single set of axes (there should be only one panel in the figure you create), but use Matplotlib/Pandas plotting functionality to make the faces of the histogram boxes somewhat transparent, so both histograms are visible.
# * Include a legend and label your axes.
# * Comment on the results. Does your figure suggest that some age ranges are more or less likely to have survived the disaster than other ages? Fully explain your reasoning and use your figure to justify your conclusions.
# * If you noticed some relationship between age and likelihood of survival, what is one possible explanation?

# %%
my_bins = range(0,85,5)
print("bin edges = ", list(my_bins))
# Initialize figure 
fig, ax0 = plt.subplots(figsize=(16,8))

filtered_dfTitanic = dfTitanic[(dfTitanic['Survived'] == 1)]

# Plot histogram 
dfTitanic.hist(column = "Age", ax=ax0, bins=my_bins, label="Total Passengers",
               color='coral', edgecolor='black', alpha=0.1);

filtered_dfTitanic.hist(column = "Age", ax=ax0, bins=my_bins, label="Survived Passengers",
               color='seagreen', edgecolor='black', alpha=0.1);

# Add labels
plt.title('Age of Passengers, Survivors on Titanic')
plt.xlabel('Age of Passengers')
plt.ylabel('Number of Passengers')
plt.legend();
# Out:
# bin edges =  [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75, 80]

# %% [markdown]
# It seemed as though the middle ages had the best survival rate. I would say that the children that survived had it fairly easy because the adults would help them. The same could be said for any adult over 50. The majority of the younger adult passangers seemed to be able to help themselves through the struggle.

# %% [markdown]
# **Part F:** In Part E, we plotted two *density* histograms, showing the distributions of ages of passengers that survived or did not survive the Titanic disaster. Why would it be misleading for us to have plotted these as *frequency* histograms instead?

# %% [markdown]
# It would be misleading for us to plot these as frequency histograms because instead of showing a even bin width, there would be a wider bin. This would be misleading because it wouldn't show the exact age, or groups thereof.

# %% [markdown]
# **Part G**: Do the data suggest class warfare, male chivalry, or some combination of both characteristics in the final hours aboard the Titanic?  Justify your conclusion based on the computations done above, or do any other analysis that you like, but be sure to clearly justify your conclusion.

# %%
my_bins = range(0,85,5)
print("bin edges = ", list(my_bins))
# Initialize figure 
fig, ax0 = plt.subplots(figsize=(16,8))

ms_dfTitanic = dfTitanic[(dfTitanic['Sex'] == "male") & (dfTitanic['Survived'] == 1)]
fs_dfTitanic = dfTitanic[(dfTitanic['Sex'] == "female") & (dfTitanic['Survived'] == 1)]

# Plot histogram 
fs_dfTitanic.hist(column = "Age", ax=ax0, bins=my_bins, label="Female, Survived",
               color='coral', edgecolor='black', alpha=0.1);

ms_dfTitanic.hist(column = "Age", ax=ax0, bins=my_bins, label="Male, Survived",
               color='seagreen', edgecolor='black', alpha=0.1);

# Add labels
plt.title('Surviving Men vs Women, Age on Titanic')
plt.xlabel('Age of Survivors')
plt.ylabel('Number of Passengers')
plt.legend();
# Out:
# bin edges =  [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75, 80]

# %% [markdown]
# It seemed as though there was both, classwarefare and chivarly going on during the titanic's final moments. There are a high number of both female suvivors and elitist survivors. I made a second graph to show the number of female survivors that survived by age vs the number of male survivors that survived by age. I broke down the data earlier like this:
#
# * 714 total people on the ship with information.
# * 279 peeps survived the disaster
# * 188 women survived the disaster
# * 91 men survived the disaster
# * 72 women in Pclass 1 survived the disaster
# * 54 women in Pclass 2 survived the disaster
# * 62 women in Pclass 3 survived the disaster
# * 36 men in Pclass 1 survived the disaster
# * 16 men in Pclass 2 survived the disaster
# * 39 men in Pclass 3 survived the disaster
# * 108 passengers in Pclass 1 survived the disaster
# * 70 passengers in Pclass 2 survived the disaster
# * 101 passengers in Pclass 3 survived the disaster
#
# From this, we can clearly see that there was a chivalry aspect. The female number of survivors towered over the male survivors. I wouldn't say that there was a case of cass warefare. There may have been for females, being that Pclass1 has more survivors than Pclass2 or Pclass3, however the numbers are not that far apart.
#
# Confirmation: Chivalry

# %% [markdown]
# [Back to top](#top)
#
# <br>
#
# <a/ id='p5'></a>
#
# ### (25 pts) Problem 5 - FCQ Data from Days of Yore
# ---
#
# The `fcq_data.csv` data set on Canvas contains about 12 full academic years of Faculty Course Questionnaire (FCQ) data from the University of Colorado Boulder. The data include the year and term (fall or spring), the course subject and number, the distribution of grades, and other such information. The file `fcq_data_info.xlsx` contains some **metadata**, which describes what all of the columns in the main data file are, and how to interpret some of the measurements. Note that some of the columns from the original data set have been removed in order to make the file size a bit more manageable.
#
# First, load the data file, and check out what are all of the available column headers.

# %%
df = pd.read_csv("fcq_data.csv")
print(df.columns)
df
# Out:
# Index(['YearTerm', 'Subject', 'Course', 'CourseTitle', 'Activity_Type',
#        'Hours', 'N_EOT', 'N_ENROLL', 'N_GRADE', 'AVG_GRD', 'PCT_A', 'PCT_B',
#        'PCT_C', 'PCT_D', 'PCT_F', 'PCT_C_MINUS_OR_BELOW', 'PCT_DF', 'PCT_DFW',
#        'PCT_WDRAW', 'PCT_INCOMP', 'N_PASS', 'N_NOCRED', 'N_INCOMP',
#        'Workload_Raw', 'Workload_Hrs_Wk', 'AvgCourse', 'AvgInstructor',
#        'N_Ret'],
#       dtype='object')
#        YearTerm Subject  Course  \
# 0         20067    ARCH    3114
# 1         20067    ARCH    3214
# 2         20067    ARCH    4010
# 3         20067    ARCH    4010
# 4         20067    ARCH    4010
# 5         20067    ENVD    1004
# 6         20067    ENVD    2001
# 7         20067    ENVD    2002
# 8         20067    ENVD    2003
# 9         20067    ENVD    2052
# 10        20067    ENVD    2110
# 11        20067    ENVD    2152
# 12        20067    ENVD    2352
# 13        20067    ENVD    3001
# 14        20067    ENVD    3015
# ...

# %% [markdown]
# **Part A:** Suppose we want to restrict our attention to only undergraduate classes in the Computer Science department. Create a new DataFrame called `dfC` consisting only of undergraduate computer science classes. You may decide for yourself how to obtain only the rows corresponding to **undergraduate** and **computer science** courses. How many data points are there total?

# %%
dfC = df[(df['Subject'] == 'CSCI') & (df['Course'] < 5000)] #Assuming under 5000 is undergraduate class ask prof tony
dfC
# Out:
#        YearTerm Subject  Course  \
# 2511      20067    CSCI    1200
# 2512      20067    CSCI    1300
# 2513      20067    CSCI    1300
# 2514      20067    CSCI    1300
# 2515      20067    CSCI    2270
# 2516      20067    CSCI    2830
# 2517      20067    CSCI    3104
# 2518      20067    CSCI    3155
# 2519      20067    CSCI    3202
# 2520      20067    CSCI    3287
# 2521      20067    CSCI    3308
# 2522      20067    CSCI    3434
# 2523      20067    CSCI    3656
# 2524      20067    CSCI    3702
# 2525      20067    CSCI    4229
# 2526      20067    CSCI    4273
# 2527      20067    CSCI    4308
# 2528      20067    CSCI    4448
# 2529      20067    CSCI    4830
# 2530      20067    CSCI    4838
# 5189      20071    CSCI    1200
# 5190      20071    CSCI    1300
# 5191      20071    CSCI    2270
# 5192      20071    CSCI    3104
# 5193      20071    CSCI    3155
# 5194      20071    CSCI    3434
# 5195      20071    CSCI    3656
# 5196      20071    CSCI    3753
# ...

# %% [markdown]
# **Part B:** Using the undergraduate computer science courses DataFrame and the `isnull()` and/or `notnull()` (or `isna`/`notna`) methods in Pandas, determine which column(s) in are missing any data. Also using Pandas methods, report how many values are missing from each of those column(s). Finally, use the `dropna()` method to remove any rows that are missing data. For the remainder of this problem, use the cleaned DataFrame for analysis. How many data points are there in the cleaned DataFrame?

# %%
dfC.notnull().sum()
# Out:
# YearTerm                617
# Subject                 617
# Course                  617
# CourseTitle             617
# Activity_Type           617
# Hours                   617
# N_EOT                   617
# N_ENROLL                617
# N_GRADE                 617
# AVG_GRD                 617
# PCT_A                   617
# PCT_B                   617
# PCT_C                   617
# PCT_D                   617
# PCT_F                   617
# PCT_C_MINUS_OR_BELOW    617
# PCT_DF                  617
# PCT_DFW                 617
# PCT_WDRAW               617
# PCT_INCOMP              617
# N_PASS                  617
# N_NOCRED                617
# N_INCOMP                617
# Workload_Raw            590
# Workload_Hrs_Wk         590
# AvgCourse               590
# AvgInstructor           590
# N_Ret                   594
# dtype: int64

# %%
dfC.isnull().sum()
# Out:
# YearTerm                 0
# Subject                  0
# Course                   0
# CourseTitle              0
# Activity_Type            0
# Hours                    0
# N_EOT                    0
# N_ENROLL                 0
# N_GRADE                  0
# AVG_GRD                  0
# PCT_A                    0
# PCT_B                    0
# PCT_C                    0
# PCT_D                    0
# PCT_F                    0
# PCT_C_MINUS_OR_BELOW     0
# PCT_DF                   0
# PCT_DFW                  0
# PCT_WDRAW                0
# PCT_INCOMP               0
# N_PASS                   0
# N_NOCRED                 0
# N_INCOMP                 0
# Workload_Raw            27
# Workload_Hrs_Wk         27
# AvgCourse               27
# AvgInstructor           27
# N_Ret                   23
# dtype: int64

# %%
dfC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 617 entries, 2511 to 73606
# Data columns (total 28 columns):
# YearTerm                617 non-null int64
# Subject                 617 non-null object
# Course                  617 non-null int64
# CourseTitle             617 non-null object
# Activity_Type           617 non-null object
# Hours                   617 non-null int64
# N_EOT                   617 non-null int64
# N_ENROLL                617 non-null int64
# N_GRADE                 617 non-null float64
# AVG_GRD                 617 non-null float64
# PCT_A                   617 non-null float64
# PCT_B                   617 non-null float64
# PCT_C                   617 non-null float64
# PCT_D                   617 non-null float64
# PCT_F                   617 non-null float64
# PCT_C_MINUS_OR_BELOW    617 non-null float64
# PCT_DF                  617 non-null float64
# PCT_DFW                 617 non-null float64
# PCT_WDRAW               617 non-null float64
# ...

# %%
dfC = dfC.dropna()
dfC
# Out:
#        YearTerm Subject  Course  \
# 2511      20067    CSCI    1200
# 2512      20067    CSCI    1300
# 2513      20067    CSCI    1300
# 2514      20067    CSCI    1300
# 2515      20067    CSCI    2270
# 2516      20067    CSCI    2830
# 2517      20067    CSCI    3104
# 2518      20067    CSCI    3155
# 2519      20067    CSCI    3202
# 2520      20067    CSCI    3287
# 2521      20067    CSCI    3308
# 2522      20067    CSCI    3434
# 2523      20067    CSCI    3656
# 2524      20067    CSCI    3702
# 2525      20067    CSCI    4229
# 2526      20067    CSCI    4273
# 2527      20067    CSCI    4308
# 2528      20067    CSCI    4448
# 2529      20067    CSCI    4830
# 2530      20067    CSCI    4838
# 5189      20071    CSCI    1200
# 5190      20071    CSCI    1300
# 5191      20071    CSCI    2270
# 5192      20071    CSCI    3104
# 5193      20071    CSCI    3155
# 5194      20071    CSCI    3434
# 5195      20071    CSCI    3656
# 5196      20071    CSCI    3753
# ...

# %% [markdown]
# **Part C:** One might hypothesize that students' grades are higher in one credit-hour courses than in regular lecture sections. Note that `Hours` corresponds to the number of credit-hours a class is worth, and that Average Grades are provided in the data set on a GPA-scale (4=A, 3=B, and so on).
#
# Compute the mean and median Average Grade for all undergraduate Computer Science courses, and for only the one credit-hour undergraduate Computer Science courses. Report all four of these numbers, and comment on the results. Does your calculation seem to support our hypothesis or not?

# %%
lec_dfC = dfC[(dfC['Activity_Type'] == "LEC - Lecture")] #bc the instructions specifically said LECTURE SECTIONS
one_dfC = dfC[(dfC['Hours'] == 1)]
thr_dfC = dfC[(dfC['Hours'] == 3) & (dfC['Activity_Type'] == "LEC - Lecture")]
fou_dfC = dfC[(dfC['Hours'] == 4) & (dfC['Activity_Type'] == "LEC - Lecture")]
#made four data sets for each hour class

# all undergraduate average
all_cred_tot = lec_dfC['AVG_GRD'].sum()
#print(all_cred_tot)
all_cred_num = lec_dfC['AVG_GRD'].count()
#print(all_cred_num)
all_cred_avg = all_cred_tot / all_cred_num
print('all credit hour undergraduate average:', all_cred_avg)

# all undergraduate median
all_cred_med = lec_dfC['AVG_GRD'].sort_values().median()
print('all credit hour undergraduate median:', all_cred_med)

# one credit hour undergraduate average
one_cred_tot = one_dfC['AVG_GRD'].sum()
#print(one_cred_tot)
one_cred_num = one_dfC['AVG_GRD'].count()
#print(one_cred_num)
one_cred_avg = one_cred_tot / one_cred_num
print('one credit hour undergraduate average:', one_cred_avg)

# one credit hour undergraduate median
one_cred_med = one_dfC['AVG_GRD'].sort_values().median()
print('one credit hour undergraduate median:', one_cred_med)

# three credit hour undergraduate average
thr_cred_tot = thr_dfC['AVG_GRD'].sum()
#print(thr_cred_tot)
thr_cred_num = thr_dfC['AVG_GRD'].count()
#print(thr_cred_num)
thr_cred_avg = thr_cred_tot / thr_cred_num
print('three credit hour undergraduate average:', thr_cred_avg)

# three credit hour undergraduate median
thr_cred_med = thr_dfC['AVG_GRD'].sort_values().median()
print('three credit hour undergraduate median:', thr_cred_med)

# four credit hour undergraduate average
fou_cred_tot = fou_dfC['AVG_GRD'].sum()
#print(fou_cred_tot)
fou_cred_num = fou_dfC['AVG_GRD'].count()
#print(fou_cred_num)
fou_cred_avg = fou_cred_tot / fou_cred_num
print('four credit hour undergraduate average:', fou_cred_avg)


# four credit hour undergraduate median
fou_cred_med = fou_dfC['AVG_GRD'].sort_values().median()
print('four credit hour undergraduate median:', fou_cred_med)
# Out:
# all credit hour undergraduate average: 3.225145299145299
# all credit hour undergraduate median: 3.26
# one credit hour undergraduate average: 3.532608695652174
# one credit hour undergraduate median: 3.52
# three credit hour undergraduate average: 3.321792717086835
# three credit hour undergraduate median: 3.38
# four credit hour undergraduate average: 3.033990384615384
# four credit hour undergraduate median: 2.98

# %% [markdown]
# I was curious to see whether or not there would be much descrepancy between the classes. Surprisingly, the one credit hour average and median is much lower than I expected. I figured that the one credit hour median and average for lectures would be over $3.5$. I hypothesized that the one credit hour courses' average and median would be the highest, followed by the three credit hour courses' average and median, then the total undergraduate courses average grades average and median, and that the lowest grades would be the  by the four credit hour courses'average and median. Because of classes I have taken in the past, the four credit hour courses were the toughest, required the most work, and had the hardest test. The three credit hour courses were hard, but I had some that were easy A's. The one credit hour courses I hypothesized to all be over 3.5 for the average grades.
#
# I  broke down the data by credit hours to test my hypothesis. To make the math neater, I rounded off to two decimal places.
# - all credit hour undergraduate average: $3.22$
# - all credit hour undergraduate median: $3.26$
# - one credit hour undergraduate average: $3.48$
# - one credit hour undergraduate median: $3.46$
# - three credit hour undergraduate average: $3.32$
# - three credit hour undergraduate median: $3.38$
# - four credit hour undergraduate average: $3.03$
# - four credit hour undergraduate median: $2.98$
#
# Basedon the data, it is clear that the one credit hour courses had the highest grades:
# - one credit hour undergraduate average: $3.48$
# - one credit hour undergraduate median: $3.46$
#
# Following these grades came the three credit hour courses:
# - three credit hour undergraduate average: $3.32$
# - three credit hour undergraduate median: $3.38$
#
# Third, the total credit hour for undergraduate courses:
# - all credit hour undergraduate average: $3.22$
# - all credit hour undergraduate median: $3.26$
#
# And then lastly, the dredded four credit hour course grades:
# - four credit hour undergraduate average: $3.03$
# - four credit hour undergraduate median: $2.98$
#
# I think these grades are for the reason I made the hypothesis that the one credit hour courses will have the highest grades. The total lecture average grades takes into account the four and three credit hour lectures. As stated previously, there are some four and three credit hour courses that require plenty of studying, homework, projects, and have very rigious test. This brings down the GPA for many students in these classes.
#
# My hypothesis proved to be confirmed.

# %% [markdown]
# **Part D:** Another hypothesis one might want to test using this data set is whether or not students' grades are different based on the course *level* - lower-division (1000s and 2000s) versus upper-division (3000s and 4000s). Create side-by-side box-and-whisker plots to compare the average grades of lower-division computer science courses versus upper-division computer science courses.  Use the box-and-whisker plot conventions discussed in lecture, and be sure to include a legend and label your axes.
#
# Comment on the results. Does your figure suggest there is a difference in the distribution of average course grades, depending on whether a class is lower- or upper-division? If you noticed a difference between the two distributions, what is one cause that could explain this difference? Fully explain your reasoning.

# %%
upp_dfC = dfC[(dfC['Course'] >= 3000) & (dfC['Activity_Type'] == "LEC - Lecture")]

#low_dfC.head()

boxplot0 = upp_dfC.boxplot(column=['AVG_GRD'])

# Add labels
plt.title('Lower division avaerage course grades')
plt.xlabel('Lower Division Courses')
plt.ylabel('Average Grade')
plt.legend();
# Out:
# No handles with labels found to put in legend.

# %%
low_dfC = dfC[(dfC['Course'] < 3000) & (dfC['Activity_Type'] == "LEC - Lecture")]

#upp_dfC.head()

boxplot1 = low_dfC.boxplot(column=['AVG_GRD'])

# Add labels
plt.title('Upper division avaerage course grades')
plt.xlabel('upper division course Level')
plt.ylabel('Average Grade')
plt.legend();
# Out:
# No handles with labels found to put in legend.

# %%
# basic plot
fig, axs = plt.subplots(2, 2)


axs[0, 0].boxplot(low_dfC['AVG_GRD'], 0, 'rs')
axs[0, 0].set_title('Lower Division Average Grades')
axs[0, 0].set_ylabel('Average Grades')
axs[0, 0].set_xlabel('Lower Division Course')


axs[0, 1].boxplot(upp_dfC['AVG_GRD'], 0, 'rs')
axs[0, 1].set_title('Upper Division Average Grade')
axs[0, 1].set_ylabel('Average Grades')
axs[0, 1].set_xlabel('Upper Division Course')


fig.subplots_adjust(left=0, right=2, bottom=0, top=4, hspace=0.5, wspace=0.5)

fig.text(0.5, 1.0, 'Median - red thin line', backgroundcolor='r', color='white', size='xx-large')
fig.text(0.5, 1.12, 'Quartiles', backgroundcolor='black', color='white', size='xx-large')
fig.text(0.5, 1.24, 'Outliers - red square', backgroundcolor='r', color='white', size='xx-large')
fig.text(0.5, 1.36, 'Lower Division Course Average Grade - Left', backgroundcolor='blue', color='white', size='xx-large')
fig.text(0.5, 1.48, 'Upper Division Course Average Grade - Right', backgroundcolor='brown', color='white', size='xx-large')
fig.text(0.5, 1.60, 'Legend', backgroundcolor='Silver', color='Black', size='xx-large')
#legend on the bottom two
plt.show()

# %% [markdown]
# **Part E:** One more hypothesis we might want to explore is whether or not there has actually been a large increase in Computer Science enrollments in recent years. There are 12 academic years of data, which means there are 24 distinct semesters (from Fall 2006 to Spring 2018). For each semester, compute the total number of students enrolled in Computer Science courses. Note that you will almost certainly be counting some students twice (or more!), but that's okay - this is still a good measure of the total demand for Computer Science classes. Use the total number of students enrolled at the end of the term as the number of students for each class.
#
# Make a plot of the total number of Computer Science students versus the semester, with the most recent semester (Spring 2018) on the right and most distant past (Fall 2006) on the left. Label your axes. For the semester axis (the x-axis), label with the actual semester as a character string, like "Fall 2006" or "Spring 2007", for example. You may want to look up how to rotate the x-tick labels in order to make the semester name labels fit nicely. Comment on the results and any interesting trends or patterns you notice in Computer Science enrollment numbers.

# %%
dfC.head()
ax = plt.gca()
bar_year_terms = dfC.groupby('YearTerm')['N_ENROLL'].sum().plot(kind='bar', figsize=(16,9), ax=ax)
yearlabels=['Fall 2006',
           'Spring 2007', 'Fall 2007',
           'Spring 2008', 'Fall 2008',
           'Spring 2009', 'Fall 2009',
           'Spring 2010', 'Fall 2010',
           'Spring 2011', 'Fall 2011',
           'Spring 2012', 'Fall 2012',
           'Spring 2013', 'Fall 2013',
           'Spring 2014', 'Fall 2014',
           'Spring 2015', 'Fall 2015',
           'Spring 2016', 'Fall 2016',
           'Spring 2017', 'Fall 2017',
           'Spring 2018']
ax.set_xticklabels(yearlabels, rotation=45)
plt.title('Year Term vs Total Enrollment')
plt.xlabel('Year Term')
plt.ylabel('Total Enrollment')
plt.legend(); #not sure why this didnt change per year term
plt.show()

# %% [markdown]
# It seems as though there is a general increasing number of students in the past years. Interestingly, the number of students in the Fall semester is generally higher than the number of students in the Spring semester. I would also hypothesize based on this data that the grades of the courses in the fall semester are lower than the grades in the spring semester. Reason being, the students from the Fall semester dropped, changed, or are retaking classes that they may not have done well in.

# %% [markdown]
# **Part F:** What is one way we could determine whether or not the Computer Science total enrollment is going up more than we should expect?

# %% [markdown]
# One way we could do it is by finding the average increase in students from academic year to academic year. In other words, find the difference between the average student population from Fall 2006 and Spring 2007 to the average student population from Fall 2007 to Spring 2008. We continue this throughout every academic year. Based on the graph, there won't seem to be a major increase until the 2012-2013 academic year. Since then, the increase of students appear to be very high.

# %% [markdown]
# **Part G:** Formulate another interesting question you could potentially answer using this data set. You do not need to actually answer it, but just frame the question clearly. What are some of the relevant column(s) in the data set?

# %% [markdown]
# We see a general increasement in population. I would want to know which group of students performed the best and under what teachers. For example, the freshmen three years ago are juniors now. How did those freshmen do in their beginning classes vs how they are doing now? Have their grades stayed consistent? Which professors have the most enrollment and best average grades?
#
# One of the facts I would be personally interested in is which professors required the most work compared to the grades? I am in the boat where I don't mind doing a lot (and I mean a lot) of work for an A. I don't want to spend hours on a homework assignment if it will be graded very harshly and I will only get a B in the class. In the mind of a student, that is a huge blow to morale and likely to get a professor rated poorly on an FCQ. For me, finding out which professor and course had the best balance means that I can take a class, do a heavy load of work and actually learn from the work, and be tested on how much I actually learned rather than do a ton of work for grades that are not so well.

# %% [markdown]
# [Back to top](#top)
